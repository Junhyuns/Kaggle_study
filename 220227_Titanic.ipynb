# %%
# 라이브러리 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# 데이터 불러오기
data = pd.read_csv('data/train.csv')

# %%
# 데이터 feature들 확인하기
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# 데이터 확인하기
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 데이터 결측치 확인하기
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Age, Cabin, Embarked 변수들이 결측치를 가지고 있다. 이는 추후에 수정할 것이다.

# %%
# 데이터 타입 확인하기
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# 생존한 인원 확인하기
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.05],autopct='%1.1f%%',ax=ax[0])
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
# 성별별 생존자 수 확인하기
data.groupby(['Sex', 'Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
# 성별 별로 생존자 비율 확인하기
f,ax=plt.subplots(1,2,figsize=(16,6))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survival rate')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %%
# 성별 별로 생존자 비율 확인하기
f,ax=plt.subplots(1,2,figsize=(16,6))
data[['Sex','P']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survival rate')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %%
# 객실별 생존자 비율 확인하기
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_01db906c_97d1_11ec_a8be_845cf3229213row0_col0,#T_01db906c_97d1_11ec_a8be_845cf3229213row1_col1,#T_01db906c_97d1_11ec_a8be_845cf3229213row1_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_01db906c_97d1_11ec_a8be_845cf3229213row0_col1{
#             background-color:  #cee666;
#             color:  #000000;
#         }#T_01db906c_97d1_11ec_a8be_845cf3229213row0_col2{
#             background-color:  #f4fa66;
#             color:  #000000;
#         }#T_01db906c_97d1_11ec_a8be_845cf3229213row1_col0{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_01db906c_97d1_11ec_a8be_845cf3229213row2_col0{
#             background-color:  #60b066;
#             color:  #000000;
#         }#T_01db906c_97d1_11ec_a8be_845cf3229213row2_col1{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_01db906c_97d1_11ec_a8be_845cf3229213row2_col2{
#             background-color:  #90c866;
#             color:  #000000;
#         }#T_01db906c_97d1_11ec_a8be_845cf3229213row3_col0,#T_01db906c_97d1_11ec_a8be_845cf3229213row3_col1,#T_01db906c_97d1_11ec_a8be_845cf3229213row3_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_01db906c_97d1_11ec_a8be_845cf3229213" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_01db906c_97d1_11ec_a8be_845cf3229213level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_01db906c_97d1_11ec_a8be_845cf3229213row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_01db906c_97d1_11ec_a8be_845cf3229213row0_col1" class="data row0 col1" >136</td>
#                         <td id="T_01db906c_97d1_11ec_a8be_845cf3229213row0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_01db906c_97d1_11ec_a8be_845cf3229213level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_01db906c_97d1_11ec_a8be_845cf3229213row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_01db906c_97d1_11ec_a8be_845cf3229213row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_01db906c_97d1_11ec_a8be_845cf3229213row1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_01db906c_97d1_11ec_a8be_845cf3229213level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_01db906c_97d1_11ec_a8be_845cf3229213row2_col0" class="data row2 col0" >372</td>
#                         <td id="T_01db906c_97d1_11ec_a8be_845cf3229213row2_col1" class="data row2 col1" >119</td>
#                         <td id="T_01db906c_97d1_11ec_a8be_845cf3229213row2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_01db906c_97d1_11ec_a8be_845cf3229213level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_01db906c_97d1_11ec_a8be_845cf3229213row3_col0" class="data row3 col0" >549</td>
#                         <td id="T_01db906c_97d1_11ec_a8be_845cf3229213row3_col1" class="data row3 col1" >342</td>
#                         <td id="T_01db906c_97d1_11ec_a8be_845cf3229213row3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %%
# 객실별 생존자 비율 확인하기
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %%
# 성별과 객실을 고려한 생존자 비율 확인하기
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_2cc9ccfe_97d1_11ec_a536_845cf3229213row0_col0,#T_2cc9ccfe_97d1_11ec_a536_845cf3229213row0_col1,#T_2cc9ccfe_97d1_11ec_a536_845cf3229213row0_col3,#T_2cc9ccfe_97d1_11ec_a536_845cf3229213row3_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_2cc9ccfe_97d1_11ec_a536_845cf3229213row0_col2,#T_2cc9ccfe_97d1_11ec_a536_845cf3229213row1_col2{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_2cc9ccfe_97d1_11ec_a536_845cf3229213row1_col0{
#             background-color:  #96cb66;
#             color:  #000000;
#         }#T_2cc9ccfe_97d1_11ec_a536_845cf3229213row1_col1{
#             background-color:  #a3d166;
#             color:  #000000;
#         }#T_2cc9ccfe_97d1_11ec_a536_845cf3229213row1_col3{
#             background-color:  #cfe766;
#             color:  #000000;
#         }#T_2cc9ccfe_97d1_11ec_a536_845cf3229213row2_col0{
#             background-color:  #a7d366;
#             color:  #000000;
#         }#T_2cc9ccfe_97d1_11ec_a536_845cf3229213row2_col1,#T_2cc9ccfe_97d1_11ec_a536_845cf3229213row2_col3{
#             background-color:  #85c266;
#             color:  #000000;
#         }#T_2cc9ccfe_97d1_11ec_a536_845cf3229213row2_col2{
#             background-color:  #6eb666;
#             color:  #000000;
#         }#T_2cc9ccfe_97d1_11ec_a536_845cf3229213row3_col0{
#             background-color:  #cde666;
#             color:  #000000;
#         }#T_2cc9ccfe_97d1_11ec_a536_845cf3229213row3_col1{
#             background-color:  #f0f866;
#             color:  #000000;
#         }#T_2cc9ccfe_97d1_11ec_a536_845cf3229213row3_col3{
#             background-color:  #f7fb66;
#             color:  #000000;
#         }#T_2cc9ccfe_97d1_11ec_a536_845cf3229213row4_col0,#T_2cc9ccfe_97d1_11ec_a536_845cf3229213row4_col1,#T_2cc9ccfe_97d1_11ec_a536_845cf3229213row4_col2,#T_2cc9ccfe_97d1_11ec_a536_845cf3229213row4_col3{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213level0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#                         <th id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213level1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213row0_col0" class="data row0 col0" >3</td>
#                         <td id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213row0_col1" class="data row0 col1" >6</td>
#                         <td id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213row0_col2" class="data row0 col2" >72</td>
#                         <td id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213row0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213level1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213row1_col0" class="data row1 col0" >91</td>
#                         <td id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213row1_col1" class="data row1 col1" >70</td>
#                         <td id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213row1_col2" class="data row1 col2" >72</td>
#                         <td id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213row1_col3" class="data row1 col3" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213level0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#                         <th id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213level1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213row2_col0" class="data row2 col0" >77</td>
#                         <td id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213row2_col1" class="data row2 col1" >91</td>
#                         <td id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213row2_col2" class="data row2 col2" >300</td>
#                         <td id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213row2_col3" class="data row2 col3" >468</td>
#             </tr>
#             <tr>
#                                 <th id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213level1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213row3_col0" class="data row3 col0" >45</td>
#                         <td id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213row3_col1" class="data row3 col1" >17</td>
#                         <td id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213row3_col2" class="data row3 col2" >47</td>
#                         <td id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213row3_col3" class="data row3 col3" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213level0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213level1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213row4_col0" class="data row4 col0" >216</td>
#                         <td id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213row4_col1" class="data row4 col1" >184</td>
#                         <td id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213row4_col2" class="data row4 col2" >491</td>
#                         <td id="T_2cc9ccfe_97d1_11ec_a536_845cf3229213row4_col3" class="data row4 col3" >891</td>
#             </tr>
#     </tbody></table>

# %%
# 성별과 객실을 고려한 생존자 비율 확인하기
sns.factorplot('Pclass','Survived',hue='Sex',data=data)
plt.show()

# %%
# Age 정보 확인하기
print('Oldest Passenger was of:',data['Age'].max(),'Years')
print('Youngest Passenger was of:',data['Age'].min(),'Years')
print('Average Age on the ship:',data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age", hue="Survived", data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()
